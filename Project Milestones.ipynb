# %% [markdown]
# # Milestone 1 - Team 7
# ### Due March 24th 2020
# Spencer Arnold <br/>
# Ryan Hines <br/>
# Matthew Hawks <br/>
# Jacob Anderson <br/>
# Tae Kweon <br/>
# Ali Najib <br/>

# %% [markdown]
# ## Deliverable Tracking

# %% [markdown]
# <div style="display: block; float:left;"/>
#     <h3>Progress and Projections</h3>
#
# | Deliverable | Percent Complete | Percent Complete By Next Milestone | Estimated Completion Date   |
# |-------------|:-----:|:------------------------------------------|-------------------------|
# | Code        |  15%  | 40% | Apr 14 |
# | Paper       |  0%   | 10% | Apr 22 |
# | Demo        |  0%   | 0%  | May 1  |
# | Presentation|  0%   | 0%  | May 5  |

# %% [markdown]
# ### **1. What deliverable goals established in the last milestone report were accomplished to the anticipated percentage?**
#
#    At the beginning of this project, we established some preliminary goals to get kickstarted. Some of these goals are inferred.
#
#    Those goals were:
#
#    - [X] Get group member communication channels flowing.
#    - [X] Finish project proposal.
#    - [X] Amend the project proposal and discuss said amendments.
#    - [X] Get repo set up with initial files/Workspace.
#    - [X] Implement some of the PRNG code / ProjectCore code.
#    - [X] Discuss architecture group assignments in depth
#    - [X] Create Tasks and divide into those tasks for the meat of the project developement.
#
# We were able to accomplish all of these low-level initial goals to 100% completion.
#
#
# ### **2. What deliverable goals established in the last milestone report were were not accomplished to the anticipated percentage?**
#
# None
#
# ### **3. What are the main deliverable goals to meet before the next milestone report, and who is working on them?**
#
#    Goals for next milestone:
#
#   - [ ] Task 1: Creating PRNG implementations. **[Expecting > 50% completion by next milestone]**
#     * Najib Ali
#     * Jacob Anderson
#   - [ ] Task 2: Setting up predictive network / core program flow. **[Expecting > 50% completion by next milestone]**
#     * Ryan Hines
#     * Tae Kweon
#   - [ ] Task 3: Figuring out a method of logging (aggregate data to later use in our research paper as we start our trials) **[Expecting > 50% completion by next milestone]**
#     * Matthew Hawks
#   - [ ] Task 4: Designing the experiment. **[Expecting > 50% completion by next milestone]**
#     * Spencer Arnold
#
#
#   **NOTE: It has been discussed among this team that there will be pretty heavy coordination between tasks. Different people are also assisting with other tasks, including the their individual role to balance the load in tasks that are more rigorous.**
#
#
# We have abstracted a lot of the details associated with each of these tasks (for the sake of being concise as per the rubric). These details are actively being discussed in the slack and among smaller chats.
#
# ## Rubric
# - [X] Does your report have the necessary table, filled with the correct information? (4 points)
# - [X] Does your report answer the questions above clearly and concisely? (4 points)
# - [X] Does each team member have a role to play in helping to meet the goals of the next milestone? (4 points)

# %% [markdown]
# # Milestone 2 - Team 7
# ### Due March 31th 2020
# Spencer Arnold <br/>
# Ryan Hines <br/>
# Matthew Hawks <br/>
# Jacob Anderson <br/>
# Tae Kweon <br/>
# Ali Najib <br/>

# %% [markdown]
# ## Deliverable Tracking

# %% [markdown]
# <div style="display: block; float:left;"/>
#     <h3>Progress and Projections</h3>
#
# | Deliverable | Percent Complete | Percent Complete By Next Milestone | Estimated Completion Date   |
# |-------------|:-----:|:------------------------------------------|-------------------------|
# | Code        |  45%  | 85% | Apr 14 |
# | Paper       |  10%   | 65% | Apr 22 |
# | Demo        |  0%   | >35%  | May 1  |
# | Presentation|  0%   | >35%  | May 5  |

# %% [markdown]
# ### **1. What deliverable goals established in the last milestone report were accomplished to the anticipated percentage?**
#
#    In the last milestone, we established some goals.
#
#    Those goals were:
#
#    - [>50%] Task 1: Creating PRNG implementations.
#      * Najib Ali
#      * Jacob Anderson
#    - [>50%] Task 2: Setting up predictive network / core program flow.
#      * Ryan Hines
#      * Tae Kweon
#    - [>50%] Task 3: Figuring out a method of logging (aggregate data to later use in our research paper as we start our trials)
#      * Matthew Hawks
#    - [>50%] Task 4: Designing the experiment.
#      * Spencer Arnold
#
#
#    Actual completion percentage:
#
#    - [45%] Task 1: Creating PRNG implementations.
#      * Najib Ali
#      * Jacob Anderson
#    - [55%] Task 2: Setting up predictive network / core program flow.
#      * Ryan Hines
#      * Tae Kweon
#    - [45%] Task 3: Figuring out a method of logging (aggregate data to later use in our research paper as we start our trials)
#      * Matthew Hawks
#    - [40%] Task 4: Designing the experiment.
#      * Spencer Arnold
#
#
# Our goal was to get at least 50% in each task category.
#
# For task 1, we have 3/8 generators complete, plus a few percentage points with the seed generator and function header standards, so that's 37% plus a few.
#
# For task 2, we have over half of the predictive net code built, but just need to discuss and tweak some things once we get closer to stringing everything together (plugging into data inputs and logging).
#
# For task 3, we have made a lot of conceptual progress in discussions, just need to implement the code.
#
# For task 4, we have a large base of the experimental design written in terms of covering our tracks with detailed reasons on "how"/"why" we have things set up the way we do, just need to write out the experimental execution part.
#
#
#
# ### **2. What deliverable goals established in the last milestone report were were not accomplished to the anticipated percentage?**
#
# We did not accomplish our percentage goals for 3/4 of the tasks; however, we fell short only in the 5-10% interval range.
#
# ### **3. What are the main deliverable goals to meet before the next milestone report, and who is working on them?**
#
#    Goals for next milestone:
#
#   - [100%] Task 1: Creating PRNG implementations.
#     * Najib Ali
#     * Jacob Anderson
#   - [90%] Task 2: Setting up predictive network / core program flow.
#     * Ryan Hines
#     * Tae Kweon
#   - [90%] Task 3: Figuring out a method of logging (aggregate data to later use in our research paper as we start our trials)
#     * Matthew Hawks
#   - [85%] Task 4: Designing the experiment.
#     * Spencer Arnold
#
#
#   **NOTE: It has been discussed among this team that there will be pretty heavy coordination between tasks. Different people are also assisting with other tasks, including the their individual role to balance the load in tasks that are more rigorous.**
#
#
# We have abstracted a lot of the details associated with each of these tasks (for the sake of being concise as per the rubric). These details are actively being discussed in the slack and among smaller chats.
#
# ## Rubric
# - [X] Does your report have the necessary table, filled with the correct information? (4 points)
# - [X] Does your report answer the questions above clearly and concisely? (4 points)
# - [X] Does each team member have a role to play in helping to meet the goals of the next milestone? (4 points)
